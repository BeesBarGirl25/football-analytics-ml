# %%
import numpy as np
import seaborn as sns
import pandas as pd
from football_analytics.analyses.passing.features import passing_feature_columns
import football_analytics.dqa as dqa

# %%
df = pd.read_parquet("../../artifacts/features/player_level_wc2018.parquet")

# %%
df.head()
# Out:
#    player_key                           player            player_position  \
# 0      2941.0                     Ismaïla Sarr                 Right Wing
# 1      2948.0                      Nabil Fekir  Center Attacking Midfield
# 2      2954.0                  Youri Tielemans       Left Center Midfield
# 3      2974.0               Saîf-Eddine Khaoui       Left Center Midfield
# 4      2995.0  Ángel Fabián Di María Hernández                  Left Wing
#
#    mean_x_loc  mean_y_loc  def_third_pct  mid_third_pct  att_third_pct  \
# 0   70.104839   70.204301       0.153226       0.424731       0.422043
# 1   77.225108   53.095238       0.090909       0.402597       0.506494
# 2   60.751073   52.412017       0.175966       0.600858       0.223176
# 3   66.689873   48.886076       0.177215       0.449367       0.373418
# 4   82.781768   18.983425       0.093923       0.240331       0.665746
#
#    left_channel_pct  mid_channel_pct  ...  carry_angle_var_att_third  \
# 0          0.002688         0.053763  ...                   0.506484
# 1          0.203463         0.207792  ...                   0.897456
# 2          0.090129         0.343348  ...                   0.720684
# 3          0.145570         0.367089  ...                   0.658168
# 4          0.817680         0.104972  ...                   0.685570
#
#    carry_angle_mean_left_channel  carry_angle_var_left_channel  \
# 0                       0.000000                      0.000000
# 1                      11.931324                      0.487876
# 2                     141.436146                      0.665877
# 3                    -138.522412                      0.675923
# 4                      51.765438                      0.691145
#
#    carry_angle_mean_centre_channel  carry_angle_var_centre_channel  \
# 0                        45.000000                        0.292893
# 1                        39.241641                        0.596515
# 2                        33.976505                        0.510709
# 3                        44.540200                        0.518174
# 4                       -89.937304                        0.620111
#
#    carry_angle_mean_right_channel  carry_angle_var_right_channel  \
# 0                      -23.252770                       0.481536
# 1                      -14.633920                       0.771257
# 2                       -0.382901                       0.716938
# 3                      -81.907772                       0.867797
# 4                      -48.744092                       0.305555
#
#    carry_direction_entropy  max_carry_length  carry_burst_index
# 0                 1.753965         73.348483           0.673399
# 1                 1.857849         34.000000           0.312326
# 2                 1.926551         31.016125           0.378164
# 3                 1.959901         19.798990           0.234385
# 4                 1.985895         36.496575           0.462653
#
# [5 rows x 402 columns]

# %%
passing_cols = passing_feature_columns()

# %%
passing_df = df[["player_key", "player_position", "player"] + passing_cols]
passing_df.shape
# Out:
# (604, 127)

# %%
report = dqa.feature_quality_report(passing_df, group_col = "player", impossible_rules = [("pass_completed", "pass_attempted"), ("forward_passes", "passes")],)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 report = dqa.feature_quality_report(passing_df, group_col = "player", impossible_rules = [("pass_completed", "pass_attempted"), ("forward_passes", "passes")],)
#
# AttributeError: module 'football_analytics.dqa' has no attribute 'feature_quality_report'
